# %% [markdown]
# <h1 style="text-align: center;">文章标题</h1>
#
# <p style="text-align: center;">2025-9-5</p>
#
# 课程代码均在如下 GitHub 仓库开源：<https://github.com/GHe0000/xmu_machine_learning>
#
# 项目自动生成网页地址：<https://ghe0000.github.io/xmu_machine_learning>

# %% [markdown]
# ## 目录
# - [1.作业要求](#作业要求)
# - [2.思路](#思路（问题背景）)
# - [3.数值计算](#数值计算)
# - [4.解析计算](#解析计算)
# - [5.结论](#结论)
# - [6.参考资料](#参考资料)
# - [7.致谢](#致谢)
# - [8.附一：问题](#附一：问题)
# - [8.附二：学习心得](#附二：学习心得)

# %% [markdown]
# ## 作业要求

# %% [markdown]
# ## 思路（问题背景）

# %% [markdown]
# ## 数值计算

# %% [markdown]
# ### 计算前准备

# %% [markdown]
# 导入需要的库，并针对 Jupyter Notebook 进行一些设置.

# %%
import numpy as np # 数值计算库
import numba as nb # 引入 jit 来加速函数（如果需要）
import sympy as sym # 符号计算库
import matplotlib.pyplot as plt # 图像绘制
from matplotlib.backends.backend_agg import FigureCanvasAgg # 设置图像后端用
import ipywidgets as ipw # 交互控件
from IPython.display import display, Math # 打印数学公式

# 设置随机数种子确保结果的可复现性
np.random.seed(3407)

# 使用 mathjax 来在 jupyter notebook 显示数学公式
sym.init_printing(use_latex='mathjax')

# 设置 matplotlib 绘制的图像嵌入到 jupyter notebook 的方式
# %matplotlib widget

# 一个工具函数，可以让静态图片不经过 widget 直接嵌入 Jupyter notebook
# 这样图片可以直接存到 nb 文件里，而不是需要运行才能显示（类似 inline）
def display_inline(fig):
    fig.set_canvas(FigureCanvasAgg(fig))
    display(fig)

# 设置 matplotlib 使用的字体，避免出现中文问题
plt.rcParams['font.family'] = ['SimSun', 'Times New Roman']
plt.rcParams['mathtext.fontset'] = 'cm'
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import numpy as np # 数值计算库
#       2 import numba as nb # 引入 jit 来加速函数（如果需要）
#       3 import sympy as sym # 符号计算库
#       4 import matplotlib.pyplot as plt # 图像绘制
#
# ModuleNotFoundError: No module named 'numpy'

# %% [markdown]
# ## 解析计算

# %% [markdown]
# ## 结论

# %% [markdown]
# ## 参考资料

# %% [markdown]
# ## 致谢

# %% [markdown]
# ## 附一：问题

# %% [markdown]
# ## 附二：学习心得
